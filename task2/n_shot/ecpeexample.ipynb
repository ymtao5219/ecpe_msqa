# %%
from container import Container
from template import Template, Example
api_key = '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'#小陶的apikey
model = Container(api_key, 'text-davinci-003')

# %%
import os
root = '../../data_json/'
folder = 'split10'
path = os.path.join(root, folder)

text_files = [f for f in os.listdir(path) if f.endswith('.json')]
train_files = [f for f in text_files if f.endswith('train.json')]
test_files = [f for f in text_files if f.endswith('test.json')]

# %%
from dataload import load_data, parse_data
train_data = load_data(train_files, path) # data includes all files
test_data = load_data(test_files, path) # data includes all files

train_data0 = train_data[0] # first file data
test_data0 = test_data[0]

# %%
# train_data0
# Out:
#       doc_id  doc_len                     pairs  \
# 0        212       10                 [[10, 9]]
# 1        213       10                  [[2, 2]]
# 2        214       13                  [[8, 7]]
# 3        215       15                [[12, 10]]
# 4        216       13                  [[8, 7]]
# ...      ...      ...                       ...
# 1745    2101       13                  [[6, 6]]
# 1746    2102       15                 [[10, 9]]
# 1747    2103       11                 [[11, 9]]
# 1748    2104       11  [[8, 5], [8, 6], [8, 7]]
# 1749    2105       10                  [[6, 5]]
#
#                                                 clauses
# 0     [{'clause_id': '1', 'emotion_category': 'null'...
# 1     [{'clause_id': '1', 'emotion_category': 'null'...
# 2     [{'clause_id': '1', 'emotion_category': 'null'...
# 3     [{'clause_id': '1', 'emotion_category': 'null'...
# 4     [{'clause_id': '1', 'emotion_category': 'null'...
# ...                                                 ...
# 1745  [{'clause_id': '1', 'emotion_category': 'null'...
# 1746  [{'clause_id': '1', 'emotion_category': 'null'...
# 1747  [{'clause_id': '1', 'emotion_category': 'null'...
# 1748  [{'clause_id': '1', 'emotion_category': 'null'...
# 1749  [{'clause_id': '1', 'emotion_category': 'null'...
#
# [1750 rows x 4 columns]

# %%
# def parse_data(data, k=-1):
#     '''k passages'''
#     data = data[:k]
#     # result = [{'pair': e[1].pairs[0], 'clauses': e[1].clauses} for e in data.iterrows()]
#     result = []
#     for e in data.iterrows():
#         content = ''
#         emotion_c = []
#         emotion_t = []
#         index = 1
#         # print(e[1].clauses)
#         for k in e[1].clauses:
#             print(k)
#             # assert False
#             content += f'{index} ' + k['clause'] + '\n'
#             if k['emotion_category'] != 'null':
#                 emotion_c.append(k['emotion_category'])
#             if k['emotion_token'] != 'null':
#                 emotion_t.append(k['emotion_token'])  
#             index += 1
#         result.append({'content': content, 'pair': e[1].pairs[0], 'emotion_category': emotion_c, 'emotion_token': emotion_t})
#     return result

# %%
# parse_train = parse_data(train_data0, 10)
# Out:
# {'clause_id': '1', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '6月6日'}
# {'clause_id': '2', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '黄某出差到江门市新会区'}
# {'clause_id': '3', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '需半个月才能回广州'}
# {'clause_id': '4', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '她将这个消息在网上告诉了钟小枫'}
# {'clause_id': '5', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '6月9日'}
# {'clause_id': '6', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '钟小枫联系黄某'}
# {'clause_id': '7', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '称出差到香港'}
# {'clause_id': '8', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '打算购买黄金项链钻石戒指等物品'}
# {'clause_id': '9', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '准备向黄某求婚'}
# {'clause_id': '10', 'emotion_category': 'happiness', 'emotion_token': '兴奋', 'clause': '黄某兴奋不已'}
# {'clause_id': '1', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '扶个老人真的是土豪才能做的好事吗'}
# {'clause_id': '2', 'emotion_category': 'sadness', 'emotion_token': '心寒', 'clause': '南京彭宇案后多起扶老被讹案令不少路人遇事心寒选择避走'}
# {'clause_id': '3', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '然而'}
# {'clause_id': '4', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '扶老就一定会被讹吗'}
# {'clause_id': '5', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '未必'}
# {'clause_id': '6', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '此前有河源市三名法官勇扶雨中摔倒的八旬老太'}
# {'clause_id': '7', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '最近有东莞小伙撞人肇事被判赔28万多元'}
# {'clause_id': '8', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '事实证明'}
# {'clause_id': '9', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '老人一口咬定的不一定能定赔'}
# {'clause_id': '10', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '抱侥幸心态抵赖的也推脱不掉责任'}
# {'clause_id': '1', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '6月10日'}
# {'clause_id': '2', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '吴某手缠纱布回家'}
# {'clause_id': '3', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '说她把1万元钱给了前女友'}
# {'clause_id': '4', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '但还是被对方扎伤了左手'}
# {'clause_id': '5', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '并说她的前女友又索要1.5万元'}
# {'clause_id': '6', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '否则就要剁吴某的手'}
# {'clause_id': '7', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '孙女士打算报警却被吴某阻止并以分手相要挟'}
# {'clause_id': '8', 'emotion_category': 'sadness', 'emotion_token': '无奈', 'clause': '孙女士无奈之下答应再给吴某1.5万元'}
# {'clause_id': '9', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '但很快'}
# {'clause_id': '10', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '孙女士发现自己被骗了'}
# {'clause_id': '11', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '原来吴某将索要的钱都用于赌球了'}
# {'clause_id': '12', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '并输得精光'}
# {'clause_id': '13', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '手缠纱布也是装的'}
# {'clause_id': '1', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '报道称'}
# {'clause_id': '2', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '这起事件发生在本月12日'}
# {'clause_id': '3', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '这只小狗冒着近38摄氏度的高温'}
# {'clause_id': '4', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '在主人的尸体旁守候了好几个小时'}
# {'clause_id': '5', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '虽然附近就有水源和遮挡阳光的地方'}
# {'clause_id': '6', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '但小狗一直寸步不离'}
# {'clause_id': '7', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '在被动物管理部门人员带走时'}
# {'clause_id': '8', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '这只小狗不断挣扎'}
# {'clause_id': '9', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '只想返回主人身边'}
# {'clause_id': '10', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '其主人系自然死亡'}
# {'clause_id': '11', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '据信是一名流浪汉'}
# {'clause_id': '12', 'emotion_category': 'sadness', 'emotion_token': '哀伤', 'clause': '小狗在抵达收容中心后极度哀伤'}
# {'clause_id': '13', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '拒绝进食及饮水'}
# {'clause_id': '14', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '也不发出任何声响'}
# {'clause_id': '15', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '甚至不愿意抬头'}
# {'clause_id': '1', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '2014年1月24日'}
# {'clause_id': '2', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '吴某应小梅之约在衢州市衢江区樟潭街道一家宾馆见面'}
# {'clause_id': '3', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '两人再次发生有偿性关系'}
# {'clause_id': '4', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '其后'}
# {'clause_id': '5', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '小梅提出要与吴某断绝关系'}
# {'clause_id': '6', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '吴某不肯'}
# {'clause_id': '7', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '两人发生争执'}
# {'clause_id': '8', 'emotion_category': 'disgust', 'emotion_token': '厌恶', 'clause': '小梅对吴某表现出厌恶'}
# {'clause_id': '9', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '并称要叫人来'}
# {'clause_id': '10', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '吴某见小梅不念旧情'}
# {'clause_id': '11', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '每次约会都要用钱维系关系'}
# {'clause_id': '12', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '一怒之下吴某用双手用力掐小梅的脖子'}
# {'clause_id': '13', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '直至小梅死亡'}
# {'clause_id': '1', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '2014年1月24日'}
# {'clause_id': '2', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '吴某应小梅之约在衢州市衢江区樟潭街道一家宾馆见面'}
# {'clause_id': '3', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '两人再次发生有偿性关系'}
# {'clause_id': '4', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '其后'}
# {'clause_id': '5', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '小梅提出要与吴某断绝关系'}
# {'clause_id': '6', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '吴某不肯'}
# {'clause_id': '7', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '两人发生争执'}
# {'clause_id': '8', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '小梅对吴某表现出厌恶'}
# {'clause_id': '9', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '并称要叫人来'}
# {'clause_id': '10', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '吴某见小梅不念旧情每次约会都要用钱维系关系'}
# {'clause_id': '11', 'emotion_category': 'anger', 'emotion_token': '一怒之下', 'clause': '一怒之下吴某用双手用力掐小梅的脖子'}
# {'clause_id': '12', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '直至小梅死亡'}
# {'clause_id': '1', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '他只好向妻子提出离婚'}
# {'clause_id': '2', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '一直被蒙在鼓里的妻子'}
# {'clause_id': '3', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '犹如晴天霹雳'}
# {'clause_id': '4', 'emotion_category': 'anger', 'emotion_token': '气得大哭', 'clause': '气得大哭一场'}
# {'clause_id': '5', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '虽然一万个不愿意'}
# {'clause_id': '6', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '但看到丈夫情义已绝'}
# {'clause_id': '7', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '只好签了字'}
# {'clause_id': '8', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '李渡自感违心'}
# {'clause_id': '9', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '净身出户'}
# {'clause_id': '10', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '谎言连篇的情人不辞而别李渡离婚后几次向美奇提出结婚'}
# {'clause_id': '11', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '美奇却一点儿也不着急'}
# {'clause_id': '12', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '美奇之前住在妹妹的出租屋'}
# {'clause_id': '13', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '李渡提出再租一套房子住'}
# {'clause_id': '14', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '美奇说住宾馆'}
# {'clause_id': '15', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '吃饭店'}
# {'clause_id': '16', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '这多方便啊'}
# {'clause_id': '1', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '东屋的土炕上'}
# {'clause_id': '2', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '12岁的陈诒婷正哄着10岁的智障妹妹玩耍'}
# {'clause_id': '3', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '看到好心人进屋'}
# {'clause_id': '4', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '小诒婷热情地和大家打招呼'}
# {'clause_id': '5', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '妹妹看到家里来了这么多人'}
# {'clause_id': '6', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '急忙缩到姐姐的身后'}
# {'clause_id': '7', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '但身体还是禁不住地左右摇晃着'}
# {'clause_id': '8', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '小诒婷轻声安慰着妹妹'}
# {'clause_id': '9', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '妹妹从小就这样'}
# {'clause_id': '10', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '就爱摇晃身体'}
# {'clause_id': '11', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '怎么说她也停不下来'}
# {'clause_id': '12', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '小诒婷告诉记者'}
# {'clause_id': '13', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '西屋是小诒婷和妹妹的卧室'}
# {'clause_id': '14', 'emotion_category': 'surprise', 'emotion_token': '惊呆', 'clause': '好心人都被眼前的一幕惊呆了———两个小姑娘睡觉的床铺是砖块支撑替换下来的旧门板垒起来的'}
# {'clause_id': '1', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '警方消息显示'}
# {'clause_id': '2', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '华裔女子在被捕后向警方表示她是因为和孩子的父亲吵架'}
# {'clause_id': '3', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '在一怒之下才选择将婴儿丢在超市里'}
# {'clause_id': '4', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '而超市内的工作人员也表示在先前多次看到女子手持孩子父亲的照片寻人但多次未果'}
# {'clause_id': '5', 'emotion_category': 'anger', 'emotion_token': '气愤', 'clause': '因为气愤选择将自己孩童遗留在公共场合以泄恨一举'}
# {'clause_id': '6', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '华裔律师权立宏表示'}
# {'clause_id': '7', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '根据规定'}
# {'clause_id': '8', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '不论是亲生父母或监护人'}
# {'clause_id': '9', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '只要将14岁以下的孩童单独遗留'}
# {'clause_id': '10', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '并且有遗弃意图者'}
# {'clause_id': '11', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '警方皆有权将其逮捕'}
# {'clause_id': '12', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '若罪名成立'}
# {'clause_id': '13', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '可构成级刑事案件'}
# {'clause_id': '1', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '徐先生的妻子35岁左右'}
# {'clause_id': '2', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '漂亮又性感'}
# {'clause_id': '3', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '夫妻俩结婚虽然有七八年了'}
# {'clause_id': '4', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '儿子都6岁了'}
# {'clause_id': '5', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '但夫妻俩感情一直不错'}
# {'clause_id': '6', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '老公一门心思看世界杯'}
# {'clause_id': '7', 'emotion_category': 'sadness', 'emotion_token': '不高兴', 'clause': '妻子自然心里不高兴了'}
# {'clause_id': '8', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '但也没办法'}
# {'clause_id': '9', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '看完球后他叫醒妻子'}
# {'clause_id': '10', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '不料太激动了周一凌晨3点多'}
# {'clause_id': '11', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '荷兰队2∶1赢了墨西哥队'}
# {'clause_id': '12', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '挺近8世界杯八强'}
# {'clause_id': '13', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '作为荷兰队的铁杆球迷'}
# {'clause_id': '14', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '徐先生激动坏了'}
# {'clause_id': '15', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '回到房间'}
# {'clause_id': '16', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '看看妻子熟睡的脸'}
# {'clause_id': '17', 'emotion_category': 'null', 'emotion_token': 'null', 'clause': '他突然意识到最近太冷落妻子了'}
# {'clause_id': '18', 'emotion_category': 'sadness', 'emotion_token': '过意不去', 'clause': '有些过意不去'}

# %%
# for i in train_data0.iterrows():
#     print(i[1].clauses[1])
parse_train = parse_data(train_data0, 10)
parse_test = parse_data(test_data0, 10)

few_shot = [{'content': e['content'], 'pair': e['pair']} for e in parse_train]
dev = [{'content': e['content'], 'pair': e['pair']} for e in parse_test]

# %%
instruction = "Think step by step. Give a response to the question in this format blew"
question = ['Question:\n', '{$ Question needs answer}']
train = ['Examples:\n', '{$ Several representative examples of the given question with answers}']
content = ['Content:\n', '{$ Passage with index which includes the emotion-cause pairs}']

template = Template(instruction=instruction)
template(question=question, train=train, content=content)
# Out:
# [['Question:\n', '{$ Question needs answer}'],
#  ['Examples:\n',
#   '{$ Several representative examples of the given question with answers}'],
#  ['Content:\n',
#   '{$ Passage with index which includes the emotion-cause pairs}']]

# %%
question_temp1 = '''Extract emotion-cause pairs and return tuples based on the given content.
In each tuple, the first element is the index of the emotion clause and the second element is the index of cause clause.
    '''

# %%
def few_shot_ecpe(model, template, content, temp=0.7, n=2):
    train = few_shot[:5]
    question = question_temp1
    example = Example(question=question, train=train, content=content)
    completion = model.chat(template, example, temp, n)
    return completion

# %%
completion = few_shot_ecpe(model, template, dev[1]['content'], temp=0.3, n=1)
# Out:
# Think step by step. Give a response to the question in this format blew
# ---
# Question:
#  {$ Question needs answer}
# Examples:
#  {$ Several representative examples of the given question with answers}
# Content:
#  {$ Passage with index which includes the emotion-cause pairs}
# ---
# Question:
# Extract emotion-cause pairs and return tuples based on the given content.
# In each tuple, the first element is the index of the emotion clause and the second element is the index of cause clause.
#
# Examples:
# [{'content': '1 6月6日\n2 黄某出差到江门市新会区\n3 需半个月才能回广州\n4 她将这个消息在网上告诉了钟小枫\n5 6月9日\n6 钟小枫联系黄某\n7 称出差到香港\n8 打算购买黄金项链钻石戒指等物品\n9 准备向黄某求婚\n10 黄某兴奋不已\n', 'pair': [10, 9]}, {'content': '1 扶个老人真的是土豪才能做的好事吗\n2 南京彭宇案后多起扶老被讹案令不少路人遇事心寒选择避走\n3 然而\n4 扶老就一定会被讹吗\n5 未必\n6 此前有河源市三名法官勇扶雨中摔倒的八旬老太\n7 最近有东莞小伙撞人肇事被判赔28万多元\n8 事实证明\n9 老人一口咬定的不一定能定赔\n10 抱侥幸心态抵赖的也推脱不掉责任\n', 'pair': [2, 2]}, {'content': '1 6月10日\n2 吴某手缠纱布回家\n3 说她把1万元钱给了前女友\n4 但还是被对方扎伤了左手\n5 并说她的前女友又索要1.5万元\n6 否则就要剁吴某的手\n7 孙女士打算报警却被吴某阻止并以分手相要挟\n8 孙女士无奈之下答应再给吴某1.5万元\n9 但很快\n10 孙女士发现自己被骗了\n11 原来吴某将索要的钱都用于赌球了\n12 并输得精光\n13 手缠纱布也是装的\n', 'pair': [8, 7]}, {'content': '1 报道称\n2 这起事件发生在本月12日\n3 这只小狗冒着近38摄氏度的高温\n4 在主人的尸体旁守候了好几个小时\n5 虽然附近就有水源和遮挡阳光的地方\n6 但小狗一直寸步不离\n7 在被动物管理部门人员带走时\n8 这只小狗不断挣扎\n9 只想返回主人身边\n10 其主人系自然死亡\n11 据信是一名流浪汉\n12 小狗在抵达收容中心后极度哀伤\n13 拒绝进食及饮水\n14 也不发出任何声响\n15 甚至不愿意抬头\n', 'pair': [12, 10]}, {'content': '1 2014年1月24日\n2 吴某应小梅之约在衢州市衢江区樟潭街道一家宾馆见面\n3 两人再次发生有偿性关系\n4 其后\n5 小梅提出要与吴某断绝关系\n6 吴某不肯\n7 两人发生争执\n8 小梅对吴某表现出厌恶\n9 并称要叫人来\n10 吴某见小梅不念旧情\n11 每次约会都要用钱维系关系\n12 一怒之下吴某用双手用力掐小梅的脖子\n13 直至小梅死亡\n', 'pair': [8, 7]}]
# Content:
# 1 据白金跃介绍
# 2 自1988年至今
# 3 他向国家各部委提出合理化建议1000多条
# 4 并多次被各部委采纳
# 5 曾荣获国家十二五建言献策个人一等奖河北省建言献策三等奖
# 6 当日
# 7 跟中新网记者谈起建言献策的初衷
# 8 白金跃陷入回忆
# 9 并略显激动
#
#
# 183

# %%
completion.choices
# Out:
# [<OpenAIObject at 0x7f8f2d9a24f0> JSON: {
#    "finish_reason": "stop",
#    "index": 0,
#    "logprobs": null,
#    "text": "\nAnswer:\n[(7, 6), (8, 7)]"
#  }]

# %%
dev[1]['pair']
# Out:
# [9, 8]
